# %% [markdown]
# **A. Список квадратов**
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %%
[i ** 2 for i in range(a, b + 1)]

# %% [markdown]
# **B. Таблица умножения 2.0**
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %%
[[i * j for j in range(1, n + 1)] for i in range(1, n + 1)]

# %% [markdown]
# **C. Длины всех слов**
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %%
[len(word) for word in sentence.split()]

# %% [markdown]
# **D. Множество нечетных чисел**
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %%
{number for number in numbers if number % 2 == 1}

# %% [markdown]
# **E. Множество всех полных квадратов**
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %%
{number for number in numbers if number ** 0.5 == int(number ** 0.5)}

# %% [markdown]
# **F. Буквенная статистика**
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %%
{
    letter: text.lower().count(letter) for letter
    in text.translate(str.maketrans('', '', '!' + '.' + ',' + '?' + ' ' + '\n')).lower()}

# %% [markdown]
# **G. Делители**
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %%
{
    number: [i for i in range(1, number + 1) if number % i == 0] for number
    in numbers}

# %% [markdown]
# **H. Аббревиатура**
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %%
(''.join(x[0].upper() for x in string.split()))

# %% [markdown]
# **I. Преобразование в строку**
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %%
(' - '.join(str(x) for x in sorted(set(numbers))))

# %% [markdown]
# **J. RLE наоборот**
#
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %%
(''.join(x[0] * x[1] for x in rle))
